# %%
# Cell 1 — Safety env vars (always first)
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"
print("Environment variables set.")
# Out:
# Environment variables set.

# %%
# Cell 2 — Check core imports and versions
import torch
import numpy as np
import pandas as pd
import sklearn
import matplotlib
import seaborn
import scipy

print(f"PyTorch      : {torch.__version__}")
print(f"NumPy        : {np.__version__}")
print(f"Pandas       : {pd.__version__}")
print(f"Scikit-learn : {sklearn.__version__}")
print(f"Matplotlib   : {matplotlib.__version__}")
print(f"Seaborn      : {seaborn.__version__}")
print(f"SciPy        : {scipy.__version__}")
# Out:
# PyTorch      : 2.10.0
# NumPy        : 2.4.2
# Pandas       : 3.0.0
# Scikit-learn : 1.8.0
# Matplotlib   : 3.10.8
# Seaborn      : 0.13.2
# SciPy        : 1.17.0

# %%
# Cell 3 — Confirm MPS device
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"Device in use: {device}")

# Quick tensor smoke test on MPS
x = torch.rand(3, 3).to(device)
y = torch.rand(3, 3).to(device)
print(f"Matrix multiply on {device}:\n", (x @ y).cpu())
print("\nAll checks passed. Ready to proceed.")
# Out:
# Device in use: mps
# Matrix multiply on mps:
#  tensor([[0.2665, 0.7792, 0.3306],
#         [0.1835, 0.7701, 0.7987],
#         [0.1245, 0.7256, 0.7569]])
#
# All checks passed. Ready to proceed.
